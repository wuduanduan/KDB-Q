# %%
import pandas as pd

# %%
DATADIR = "/Users/CaoRu/Documents/github/KDB-Q/span_public/"

# %%
pd.read_csv(DATADIR+ "crude_oil_options.csv")
# Out:
#            date exch cc_code underly_code type_code        prod_name  \
# 0    2020-12-09  NYM     C14           CL       OOF  C14 SHORT TERM
# 1    2020-12-09  NYM     C14           CL       OOF  C14 SHORT TERM
# 2    2020-12-09  NYM     C14           CL       OOF  C14 SHORT TERM
# 3    2020-12-09  NYM     C14           CL       OOF  C14 SHORT TERM
# 4    2020-12-09  NYM     C14           CL       OOF  C14 SHORT TERM
# ..          ...  ...     ...          ...       ...              ...
# 587  2020-12-09  NYM     LO4           CL       OOF  WEEKLY CRUDE OI
# 588  2020-12-09  NYM     LO4           CL       OOF  WEEKLY CRUDE OI
# 589  2020-12-09  NYM     LO4           CL       OOF  WEEKLY CRUDE OI
# 590  2020-12-09  NYM     LO4           CL       OOF  WEEKLY CRUDE OI
# 591  2020-12-09  NYM     LO4           CL       OOF  WEEKLY CRUDE OI
#
#        fut_date    opt_date  opt_strike valuation_meth  max_array_value  \
# ...

# %%
pd.read_csv(DATADIR+ "crude_oil_futures.csv")
# Out:
#            date exch cc_code underly_code type_code        prod_name  \
# 0    2020-12-09  NYM      CL           CL       FUT  CRUDE OIL FUTUR
# 1    2020-12-09  NYM      CL           CL       FUT  CRUDE OIL FUTUR
# 2    2020-12-09  NYM      CL           CL       FUT  CRUDE OIL FUTUR
# 3    2020-12-09  NYM      CL           CL       FUT  CRUDE OIL FUTUR
# 4    2020-12-09  NYM      CL           CL       FUT  CRUDE OIL FUTUR
# ..          ...  ...     ...          ...       ...              ...
# 129  2020-12-09  NYM      CL           CL       FUT  CRUDE OIL FUTUR
# 130  2020-12-09  NYM      CL           CL       FUT  CRUDE OIL FUTUR
# 131  2020-12-09  NYM      CL           CL       FUT  CRUDE OIL FUTUR
# 132  2020-12-09  NYM      CL           CL       FUT  CRUDE OIL FUTUR
# 133  2020-12-09  NYM      CL           CL       FUT  CRUDE OIL FUTUR
#
#        fut_date    opt_date  opt_strike valuation_meth  max_array_value  \
# ...
